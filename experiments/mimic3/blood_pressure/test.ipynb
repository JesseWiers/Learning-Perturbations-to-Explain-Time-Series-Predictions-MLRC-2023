# %%
# from tint.datasets import Mimic3



mimci3 = Mimic3()
mimci3.download(sqluser="mimicuser", split="train")
# mimic3.download(sqluser="mimicuser", split="test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 from tint.datasets import Mimic3
#       3 mimci3 = Mimic3()
# ----> 4 mimci3.download(sqluser="mimicuser", split="train")
#       5 # mimic3.download(sqluser="mimicuser", split="test")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/time_interpret/lib/python3.11/site-packages/tint/datasets/mimic3.py:213, in Mimic3.download(self, sqluser, prop_train, split)
#     210 den = pd.read_sql_query(denquery, con)
#     212 # drop patients with less than 48 hour
# --> 213 den["los_icu_hr"] = (den.outtime - den.intime).astype("timedelta64[h]")
#     214 den = den[(den.los_icu_hr >= 48)]
#     215 den = den[(den.age < 300)]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/time_interpret/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
# ...
