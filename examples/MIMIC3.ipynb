# %%
# !pwd
# Out:
# /content

# %%
# !scp drive/MyDrive/time_interpret.zip sample_data/

# %%
# The following allows you to run the extremal_mask_params. Make sure that your mimic3 results.

# !python3 time_interpret/experiments/mimic3/mortality/extremal_mask_params.py --device 'cuda:0'
# Out:
# ['time_interpret', '/content/time_interpret/experiments/mimic3/mortality', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages']
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 2024-01-30 10:36:10.659821: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 10:36:10.659879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
